# %%
import json, requests
import pandas as pd
import numpy as np
import io
import random
import time
from sklearn.pipeline import make_pipeline

import os

from joblib import dump, load

import cml.data_v1 as cmldata

from random import sample
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Going to try brand new input format**

# %%
test_input = """
[{"symbol":"AAL","symbol_time":"2023-01-04 06:35:00","close":12.82,"volume":2305},{"symbol":"AAL","symbol_time":"2023-01-04 07:28:00","close":12.82,"volume":1000},{"symbol":"AAL","symbol_time":"2023-01-04 08:47:00","close":12.85,"volume":4634},{"symbol":"AAL","symbol_time":"2023-01-04 09:53:00","close":13.221,"volume":132423},{"symbol":"AAL","symbol_time":"2023-01-04 10:03:00","close":13.235,"volume":579976},{"symbol":"AAL","symbol_time":"2023-01-04 10:11:00","close":13.15,"volume":81587},{"symbol":"AAL","symbol_time":"2023-01-04 10:15:00","close":13.18,"volume":68385},{"symbol":"AAL","symbol_time":"2023-01-04 11:03:00","close":13.325,"volume":66521},{"symbol":"AAL","symbol_time":"2023-01-04 11:31:00","close":13.37,"volume":66507},{"symbol":"AAL","symbol_time":"2023-01-04 11:38:00","close":13.445,"volume":109833},{"symbol":"AAL","symbol_time":"2023-01-04 11:42:00","close":13.425,"volume":20801},{"symbol":"AAL","symbol_time":"2023-01-04 12:15:00","close":13.4,"volume":54166},{"symbol":"AAL","symbol_time":"2023-01-04 12:19:00","close":13.395,"volume":132018},{"symbol":"AAL","symbol_time":"2023-01-04 12:24:00","close":13.4101,"volume":51216},{"symbol":"AAL","symbol_time":"2023-01-04 13:00:00","close":13.4712,"volume":41993},{"symbol":"AAL","symbol_time":"2023-01-04 13:44:00","close":13.535,"volume":6060},{"symbol":"AAL","symbol_time":"2023-01-04 13:58:00","close":13.555,"volume":65771},{"symbol":"AAL","symbol_time":"2023-01-04 13:59:00","close":13.555,"volume":18366},{"symbol":"AAL","symbol_time":"2023-01-04 14:02:00","close":13.52,"volume":98415},{"symbol":"AAL","symbol_time":"2023-01-04 14:38:00","close":13.46,"volume":50502},{"symbol":"AAL","symbol_time":"2023-01-04 14:59:00","close":13.585,"volume":47684},{"symbol":"AAL","symbol_time":"2023-01-04 15:19:00","close":13.58,"volume":135242},{"symbol":"AAL","symbol_time":"2023-01-04 15:59:00","close":13.58,"volume":339229},{"symbol":"AAL","symbol_time":"2023-01-04 16:00:00","close":13.595,"volume":774468},{"symbol":"AAL","symbol_time":"2023-01-04 17:03:00","close":13.56,"volume":200},{"symbol":"AAL","symbol_time":"2023-01-05 04:51:00","close":13.58,"volume":226},{"symbol":"AAL","symbol_time":"2023-01-05 05:19:00","close":13.57,"volume":226},{"symbol":"AAL","symbol_time":"2023-01-05 07:19:00","close":13.58,"volume":786},{"symbol":"AAL","symbol_time":"2023-01-05 08:23:00","close":13.5,"volume":2235},{"symbol":"AAL","symbol_time":"2023-01-05 09:08:00","close":13.45,"volume":5438},{"symbol":"AAL","symbol_time":"2023-01-05 09:13:00","close":13.45,"volume":947},{"symbol":"AAL","symbol_time":"2023-01-05 09:23:00","close":13.46,"volume":
13.15,"volume":81587},{"symbol":"AAL","symbol_time":"2023-01-04 10:15:00","close":13.18,"volume":68385},{"symbol":"AAL","symbol_time":"2023-01-04 11:03:00","close":13.325,"volume":66521},{"symbol":"AAL","symbol_time":"2023-01-04 11:31:00","close":13.37,"volume":66507},{"symbol":"AAL","symbol_time":"2023-01-04 11:38:00","close":13.445,"volume":109833},{"symbol":"AAL","symbol_time":"2023-01-04 11:42:00","close":13.425,"volume":20801},{"symbol":"AAL","symbol_time":"2023-01-04 12:15:00","close":13.4,"volume":54166},{"symb
# ...

# %%
CONNECTION_NAME = "loki-datalake"
# ## Sample Usage to get pandas data frame
EXAMPLE_SQL_QUERY = "show databases"
# Alternate Sample Usage to provide different credentials as optional parameters
conn = cmldata.get_connection(
   CONNECTION_NAME, {"USERNAME": os.environ['PROJECT_OWNER'], "PASSWORD": "D83j8TNG#PS#jAQ"}
)

# %%
kudu_input = pd.read_csv('query-impala-319.csv')

# %%
kudu_input.sort_values(['symbol','symbol_time'],ascending=False).head()
# Out:
#     symbol          symbol_time        open        high         low  \
# 777   ZION  2023-01-10 19:19:00   51.029999   51.029999   51.020000
# 774    XOM  2023-01-10 20:00:00  109.599998  109.599998  109.599998
# 770    XOM  2023-01-10 19:58:00  109.599998  109.599998  109.599998
# 761    XOM  2023-01-10 19:55:00  109.660004  109.690002  109.660004
# 759    XOM  2023-01-10 19:43:00  109.699997  109.699997  109.699997
#
#           close  volume       last_refreshed information
# 777   51.020000     300  2023-01-11 21:08:59   Real Time
# 774  109.599998     318  2023-01-11 21:02:49   Real Time
# 770  109.599998     200  2023-01-11 21:02:49   Real Time
# 761  109.690002     273  2023-01-11 21:02:49   Real Time
# 759  109.699997     111  2023-01-11 21:02:49   Real Time

# %%
test_input = kudu_input[kudu_input['symbol'] == 'AMZN'].copy()

# %%
test_input.shape
# Out:
# (80, 9)

# %%
#kudu_input.symbol.unique()[:10]
kudu_input.groupby('symbol').size()
# Out:
# symbol
# AAL     40
# AAPL    66
# ALK      3
# AMZN    80
# BAX      1
#         ..
# WBD     32
# WDC      1
# WYNN     3
# XOM     18
# ZION     1
# Length: 90, dtype: int64

# %% [markdown]
# ### Automate the dictionary build

# %%
cols = ['symbol','symbol_time','close', 'volume']

# %%
# Model - new model- 
#model_url = 'https://modelservice.ml-6e89be47-314.loki-cdp.a465-9q4k.cloudera.site/model'
model_url = 'https://modelservice.ml-5fea65b7-abd.loki-cdp.a465-9q4k.cloudera.site/model'
# make access key environment variable
accessKey = 'mej89c35pyinv9w36ei6kyp6lgrx3kqu'

# %%
df_in = test_input[cols]

# %%
df_in.symbol.unique()
# Out:
# array(['AMZN'], dtype=object)

# %%
data_in = df_in.to_dict('records')

# %%
data_in
# Out:
# [{'symbol': 'AMZN',
#   'symbol_time': '2023-01-10 19:42:00',
#   'close': 89.94999694824219,
#   'volume': 399},
#  {'symbol': 'AMZN',
#   'symbol_time': '2023-01-10 19:59:00',
#   'close': 89.9800033569336,
#   'volume': 3542},
#  {'symbol': 'AMZN',
#   'symbol_time': '2023-01-10 19:57:00',
#   'close': 89.98999786376953,
#   'volume': 2710},
#  {'symbol': 'AMZN',
#   'symbol_time': '2023-01-10 19:52:00',
#   'close': 89.98989868164062,
#   'volume': 5054},
#  {'symbol': 'AMZN',
#   'symbol_time': '2023-01-10 19:41:00',
#   'close': 89.94999694824219,
#   'volume': 1773},
#  {'symbol': 'AMZN',
#   'symbol_time': '2023-01-10 19:39:00',
#   'close': 89.94000244140625,
#   'volume': 128},
#  {'symbol': 'AMZN',
#   'symbol_time': '2023-01-10 19:17:00',
#   'close': 89.98999786376953,
#   'volume': 1125},
#  {'symbol': 'AMZN',
#   'symbol_time': '2023-01-10 18:58:00',
#   'close': 89.94000244140625,
#   'volume': 3873},
#  {'symbol': 'AMZN',
#   'symbol_time': '2023-01-10 18:24:00',
# ...

# %%
# build embedded dictionary step 1    
request_dict1 = {"data":data_in}

request_dict = {"request":request_dict1}


# access key will be end point specific
BackDict = {"accessKey":accessKey}
BackDict.update(request_dict)
request_dict=BackDict

# %%
r10 = requests.post(model_url, data=json.dumps(request_dict),headers={'Content-Type': 'application/json'})

# %%
model_url
# Out:
# 'https://modelservice.ml-5fea65b7-abd.loki-cdp.a465-9q4k.cloudera.site/model'

# %%
request_dict
# Out:
# {'accessKey': 'mej89c35pyinv9w36ei6kyp6lgrx3kqu',
#  'request': {'data': [{'symbol': 'AMZN',
#     'symbol_time': '2023-01-10 19:42:00',
#     'close': 89.94999694824219,
#     'volume': 399},
#    {'symbol': 'AMZN',
#     'symbol_time': '2023-01-10 19:59:00',
#     'close': 89.9800033569336,
#     'volume': 3542},
#    {'symbol': 'AMZN',
#     'symbol_time': '2023-01-10 19:57:00',
#     'close': 89.98999786376953,
#     'volume': 2710},
#    {'symbol': 'AMZN',
#     'symbol_time': '2023-01-10 19:52:00',
#     'close': 89.98989868164062,
#     'volume': 5054},
#    {'symbol': 'AMZN',
#     'symbol_time': '2023-01-10 19:41:00',
#     'close': 89.94999694824219,
#     'volume': 1773},
#    {'symbol': 'AMZN',
#     'symbol_time': '2023-01-10 19:39:00',
#     'close': 89.94000244140625,
#     'volume': 128},
#    {'symbol': 'AMZN',
#     'symbol_time': '2023-01-10 19:17:00',
#     'close': 89.98999786376953,
#     'volume': 1125},
#    {'symbol': 'AMZN',
# ...

# %%
r10 = requests.post(model_url, data=json.dumps(request_dict),headers={'Content-Type': 'application/json'})

# %%
r10.json()
# Out:
# {'success': True,
#  'response': {'model_deployment_crn': 'crn:cdp:ml:us-west-1:558bc1d2-8867-4357-8524-311d51259233:workspace:7364d789-daae-47c6-951f-2ef3926b100c/46c06fbd-df7f-440c-acd7-dd08dabc0d57',
#   'prediction': {'pred_time': ['2023-01-10 20:00:00'],
#    'prediction': [-1],
#    'symbol': ['AMZN']},
#   'uuid': '5840fe29-e299-4d1a-9278-69d70775e0ec'},
#  'ReplicaID': 'market-direction-model-12-47-78849fdb84-qnm69',
#  'Size': 329,
#  'StatusCode': 200}

# %%
r9.json()['response']

# %% [markdown]
# request_dict.keys()

# %%
r9.json()['response']['prediction'].keys()
# Out:
# dict_keys(['pred_time', 'prediction', 'symbol'])

# %%
df.Name
# Out:
# 0     NVR
# 1     TER
# 2     MET
# 3    CTSH
# 4    KLAC
# 5    CSGP
# 6     ETN
# 7     IEX
# 8    AAPL
# 9     DAL
# Name: Name, dtype: object
